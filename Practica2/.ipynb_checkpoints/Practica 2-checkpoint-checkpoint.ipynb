# %%
#Práctica 2 - AAMS

# %%
### Funciones

* ¿Por qué son ventajosas las funciones para tener en sus programas?
    Porque las funciones pueden ser invocadas nuevamente en cualquier parte del código
    
* ¿Cuándo se ejecuta el código en una función: cuando se define la función o cuando se llama a la función?
    cuando se llama a la función
    
* ¿Qué enunciado crea una función?
    "def" [Espacio] Nombre de la funcion ()

* ¿Cuál es la diferencia entre una función y una llamada de función?
    Que en una defines a la funciones y a su bloque de instrucciones y la llamada simplemente invoca a la función
    
* ¿Cuántos ámbitos globales hay en un programa de Python? ¿Cuántos ámbitos locales?
    Python distingue tres tipos de variables: las variables locales y dos tipos de variables libres (globales y no locales):
Se describen como lo siguiente:
    variables locales: las que pertenecen al ámbito de la subrutina (y que pueden ser accesibles a niveles inferiores)
    variables globales: las que pertenecen al ámbito del programa principal.
    variables no locales: las que pertenecen a un ámbito superior al de la subrutina, pero que no son globales.
Recuperado de: http://www.mclibre.org/consultar/python/lecciones/python-funciones-1.html
        
* ¿Qué sucede con las variables en un ámbito local cuando se devuelve la llamada a la función?
    Al solo existir dentro de la función las variables locales no pueden ser llamadas fuera de la función por lo que hacerlo 
    produce un error en el código. 
    
* ¿Qué es un valor de retorno? ¿Puede un valor de retorno ser parte de una expresión?
    El valor de retorno es el resultado del bloque de instrucción de una función definida por el usuario.
    Dicho valor puese ser parte de una expresión si se ha llamado a la función con anterioridad
    
* Si una función no tiene una declaración de retorno, ¿cuál es el valor de retorno de una llamada a esa función?.
    Adquiere un valor return especial, "None"
* ¿Cómo puede forzar una variable en una función para referirse a la variable global?
    Si queremos asignar valor a una variable en una subrutina, pero no queremos que Python la considere local, debemos declararla en la función como global o nonlocal
    
* ¿Cuál es el tipo de datos de ```None```?
    Resultados de una función definida por el usuario para los cuales no existe un valor de retorno
    
* ¿Qué hace la declaración ```import random```?
    Importa una libreria precargada en Python llamada random la cual genera números al azar. 
    
* Si tuviera una función llamada ```randint()``` en un módulo llamado ```random```, ¿cómo lo llamaría después de importar ```random```?
    randint() = global
    
#Lista y tuplas

*¿Qué es []?
    Sintaxis para definir elementos dentro de una lista a = [1,2]
*¿Cómo asignaría el valor 'hola' como el tercer valor en una lista almacenada? en una variable llamada spam? (Supongamos que el spam contiene [2, 4, 6, 8, 10].) 
spam = [2,4,6,8,10]
spam.insert(2,"hola")

Para las siguientes tres preguntas, digamos que spam contiene la lista [2, 4, 6, 8, 10].
    
    ¿Qué evalúa spam[int ('3' * 2) / 11]?
        Obtiene el valor entero de multiplicar por dos el tercer elemento de la lista y despues dividirlo entre 11
    ¿Qué evalúa spam[-1]?
        Imprime todos los elementos de la lista
    ¿Qué evalúa el spam[: 2]?
        Imprime los elementos de la lista desde el primero hasta el de índice 2

Para las siguientes tres preguntas, digamos que bacon contiene la lista [3.14, 'cat', 11, 'cat', True].

*¿Qué evalúa bacon.index('cat')?
    Arroja el número de índice del elemento "cat"
*¿Qué evalúa bacon.append(99)?
    Añade el elemento "99" hasta el final de la lista
*¿Qué hace bacon.remove('cat')?
    Elimina el elemento "cat" de la lista
*¿Cuáles son los operadores para la concatenación de listas y la replicación de listas?
    {.extend() para concatenar listas
    operador "+" siempre que ambos sumandos sean listas
    }
    {Si queremos copiar una lista, de manera que conservemos su valor aunque modifiquemos la lista original debemos utilizar la notación de sublistas.

    lista2 = lista1[:]}
    
*¿Cuál es la diferencia entre los métodos de lista append() e insert()?
    Append() inserta un elemento al final de la lista mientras insert() inserta un elemento en un índice especificado

    *¿Cuál es la diferencia entre listas y tuplas?
Una tupla es inmutable mientras que las listas sí lo son.
